# %%
import pandas as pd

# %%
ha_costs_df = pd.read_csv('../data/mmd_heart_attack_data.csv')

# %%
ha_costs_df.head(5)
# Out:
#    year geography             measure         adjustment      analysis  \
# 0  2017    County  Average total cost  Unsmoothed actual  Base measure
# 1  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3  2017    County  Average total cost  Unsmoothed actual  Base measure
# 4  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                        domain                    condition primary_sex  \
# 0  Primary chronic conditions  Acute myocardial infarction         All
# 1  Primary chronic conditions  Acute myocardial infarction         All
# 2  Primary chronic conditions  Acute myocardial infarction         All
# 3  Primary chronic conditions  Acute myocardial infarction         All
# 4  Primary chronic conditions  Acute myocardial infarction         All
#
#   primary_age     primary_dual  fips          county    state  urban  \
# ...

# %%
ha_costs_df.tail(5)
# Out:
#       year geography             measure         adjustment      analysis  \
# 2651  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2652  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2653  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2654  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2655  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                    condition primary_sex  \
# 2651  Primary chronic conditions  Acute myocardial infarction         All
# 2652  Primary chronic conditions  Acute myocardial infarction         All
# 2653  Primary chronic conditions  Acute myocardial infarction         All
# 2654  Primary chronic conditions  Acute myocardial infarction         All
# 2655  Primary chronic conditions  Acute myocardial infarction         All
#
#      primary_age     primary_dual   fips                   county  \
# ...

# %%
ha_costs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2656 entries, 0 to 2655
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 2656 non-null   int64
#  1   geography            2656 non-null   object
#  2   measure              2656 non-null   object
#  3   adjustment           2656 non-null   object
#  4   analysis             2656 non-null   object
#  5   domain               2656 non-null   object
#  6   condition            2656 non-null   object
#  7   primary_sex          2656 non-null   object
#  8   primary_age          2656 non-null   object
#  9   primary_dual         2656 non-null   object
#  10  fips                 2656 non-null   int64
#  11  county               2656 non-null   object
#  12  state                2656 non-null   object
#  13  urban                2656 non-null   object
#  14  primary_race         2656 non-null   object
# ...

# %%
ha_costs_df.loc[ha_costs_df['state'] == 'TENNESSEE']
# Out:
#       year geography             measure         adjustment      analysis  \
# 2030  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2031  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2032  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2033  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2034  2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 2116  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2117  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2118  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2119  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2120  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                    condition primary_sex  \
# ...

# %%
tn_ha_costs = ha_costs_df.loc[ha_costs_df['state'] == 'TENNESSEE']

# %%
tn_ha_costs.shape
# Out:
# (91, 17)

# %%
tn_ha_costs['county'].nunique()
# Out:
# 91

# %%
tn_ha_costs['urban'].value_counts()
# Out:
# Rural    53
# Urban    38
# Name: urban, dtype: int64

# %% [markdown]
# End of TN ha data task

# %%
cancer_costs_df = pd.read_csv('../data/mmd_cancer_data.csv')

# %%
cancer_costs_df.head(2)
# Out:
#    year geography             measure         adjustment      analysis  \
# 0  2017    County  Average total cost  Unsmoothed actual  Base measure
# 1  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                        domain                                   condition  \
# 0  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 1  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
#
#   primary_sex primary_age     primary_dual  fips          county    state  \
# 0         All         All  Dual & non-dual  1001  Autauga County  ALABAMA
# 1         All         All  Dual & non-dual  1003  Baldwin County  ALABAMA
#
#    urban primary_race primary_denominator  analysis_value
# 0  Urban          All           undefined           19293
# 1  Rural          All           undefined           17151

# %%
cancer_costs_df.tail(2)
# Out:
#       year geography             measure         adjustment      analysis  \
# 3163  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3164  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                                   condition  \
# 3163  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3164  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
#
#      primary_sex primary_age     primary_dual   fips             county  \
# 3163         All         All  Dual & non-dual  72151  Yabucoa Municipio
# 3164         All         All  Dual & non-dual  72153    Yauco Municipio
#
#             state  urban primary_race primary_denominator  analysis_value
# 3163  PUERTO RICO  Urban          All           undefined            8008
# 3164  PUERTO RICO  Urban          All           undefined           11171

# %%
cancer_costs_df.loc[cancer_costs_df['state'] == 'TENNESSEE']
# Out:
#       year geography             measure         adjustment      analysis  \
# 2396  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2397  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2398  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2399  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2400  2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 2486  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2487  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2488  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2489  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2490  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                                   condition  \
# ...

# %%
tn_cancer_costs = cancer_costs_df.loc[cancer_costs_df['state'] == 'TENNESSEE']

# %%
tn_cancer_costs.shape
# Out:
# (95, 17)

# %%
tn_cancer_costs['county'].nunique()
# Out:
# 95

# %%
tn_cancer_costs.loc[~tn_cancer_costs['county'].isin(tn_ha_costs['county'])]
# Out:
#       year geography             measure         adjustment      analysis  \
# 2429  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2459  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2464  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2483  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                                   condition  \
# 2429  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 2459  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 2464  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 2483  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
#
#      primary_sex primary_age     primary_dual   fips            county  \
# 2429         All         All  Dual & non-dual  47067    Hancock County
# ...

# %%
tn_cancer_costs.analysis_value.value_counts()
# Out:
# 20655    1
# 19759    1
# 17316    1
# 18597    1
# 17830    1
#         ..
# 19209    1
# 18012    1
# 15454    1
# 22707    1
# 22400    1
# Name: analysis_value, Length: 95, dtype: int64

# %%
tn_cancer_costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95 entries, 2396 to 2490
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 95 non-null     int64
#  1   geography            95 non-null     object
#  2   measure              95 non-null     object
#  3   adjustment           95 non-null     object
#  4   analysis             95 non-null     object
#  5   domain               95 non-null     object
#  6   condition            95 non-null     object
#  7   primary_sex          95 non-null     object
#  8   primary_age          95 non-null     object
#  9   primary_dual         95 non-null     object
#  10  fips                 95 non-null     int64
#  11  county               95 non-null     object
#  12  state                95 non-null     object
#  13  urban                95 non-null     object
#  14  primary_race         95 non-null     object
# ...

# %%
tn_cancer_costs.isnull().sum()
# Out:
# year                   0
# geography              0
# measure                0
# adjustment             0
# analysis               0
# domain                 0
# condition              0
# primary_sex            0
# primary_age            0
# primary_dual           0
# fips                   0
# county                 0
# state                  0
# urban                  0
# primary_race           0
# primary_denominator    0
# analysis_value         0
# dtype: int64

# %% [markdown]
# End of TN cancer data task

# %%
income_df = pd.read_csv('../data/irs_county_2016.csv')

# %%
income_df.loc[income_df['STATE'] == 'TN']
# Out:
#        STATEFIPS STATE  COUNTYFIPS     COUNTYNAME  agi_stub      N1   mars1  \
# 19752         47    TN           0      Tennessee         1   39580   22400
# 19753         47    TN           0      Tennessee         2  439770  345410
# 19754         47    TN           0      Tennessee         3  717430  398720
# 19755         47    TN           0      Tennessee         4  759340  355970
# 19756         47    TN           0      Tennessee         5  396810  128390
# ...          ...   ...         ...            ...       ...     ...     ...
# 20515         47    TN         189  Wilson County         4   14400    7130
# 20516         47    TN         189  Wilson County         5    9330    2890
# 20517         47    TN         189  Wilson County         6    7160    1060
# 20518         47    TN         189  Wilson County         7   10350     780
# 20519         47    TN         189  Wilson County         8    2370     180
#
# ...

# %%
income_df.head(2)
# Out:
#    STATEFIPS STATE  COUNTYFIPS COUNTYNAME  agi_stub      N1   mars1  MARS2  \
# 0          1    AL           0    Alabama         1   26450   14680   9740
# 1          1    AL           0    Alabama         2  285760  217880  25170
#
#    MARS4    PREP  ...  N10300  A10300  N85530  A85530  N85300  A85300  N11901  \
# 0    680   17780  ...    4300    9256      70      57       0       0    2590
# 1  39740  143390  ...   70050   40569       0       0       0       0   22720
#
#    A11901  N11902  A11902
# 0    3685   11510   35079
# 1   11109  237630  263152
#
# [2 rows x 148 columns]

# %%
income_df.tail(2)
# Out:
#        STATEFIPS STATE  COUNTYFIPS     COUNTYNAME  agi_stub   N1  mars1  \
# 25534         56    WY          45  Weston County         7  460     40
# 25535         56    WY          45  Weston County         8   90      0
#
#        MARS2  MARS4  PREP  ...  N10300  A10300  N85530  A85530  N85300  \
# 25534    420      0   320  ...     460    7958       0       0       0
# 25535     80      0    80  ...      90    7195       0       0      50
#
#        A85300  N11901  A11901  N11902  A11902
# 25534       0     180     907     260    1045
# 25535     146      50    2257      30     377
#
# [2 rows x 148 columns]

# %%
TN_income = income_df.loc[income_df['STATE'] == 'TN']

# %%
TN_income.shape
# Out:
# (768, 148)

# %%
TN_income_edit = TN_income.loc[ : , ['STATE', 'COUNTYNAME', 'agi_stub', 'N1', 'mars1', 'MARS2', 'MARS4', 'N2', 'NUMDEP', 'ELDERLY', 'A00100', 'N02650', 'A02650', 'N02300', 'A02300']]

# %%
TN_income_edit.columns = ['state', 'county', 'income_bucket', 'return_count', 'single_returns', 'joint_returns', 'head_of_house_returns', 'exemptions', 'dependents', 'elderly', 'agi', 'returns_with_total_inc','total_inc_amt', 'returns_with_unemployment', 'unemployment_comp']

# %%
TN_income_edit.head(10)
# Out:
#       state           county  income_bucket  return_count  single_returns  \
# 19752    TN        Tennessee              1         39580           22400
# 19753    TN        Tennessee              2        439770          345410
# 19754    TN        Tennessee              3        717430          398720
# 19755    TN        Tennessee              4        759340          355970
# 19756    TN        Tennessee              5        396810          128390
# 19757    TN        Tennessee              6        241730           43690
# 19758    TN        Tennessee              7        298270           33380
# 19759    TN        Tennessee              8         97920            8640
# 19760    TN  Anderson County              1           390             220
# 19761    TN  Anderson County              2          5170            4010
#
#        joint_returns  head_of_house_returns  exemptions  dependents  elderly  \
# ...

# %% [markdown]
# End of TN income data task

# %%
ha_costs_df_urban = tn_ha_costs.loc[ha_costs_df['urban'] == 'Urban']
ha_costs_df_urban.analysis_value.describe()
# Out:
# count       38.000000
# mean     45748.921053
# std       7109.788921
# min      32279.000000
# 25%      40452.750000
# 50%      45496.500000
# 75%      50734.500000
# max      61541.000000
# Name: analysis_value, dtype: float64

# %%
ha_costs_df_rural = tn_ha_costs.loc[ha_costs_df['urban'] == 'Rural']
ha_costs_df_rural.analysis_value.describe()
# Out:
# count       53.000000
# mean     45773.075472
# std       6232.724885
# min      30831.000000
# 25%      41240.000000
# 50%      45384.000000
# 75%      48998.000000
# max      62641.000000
# Name: analysis_value, dtype: float64

# %%
cancer_costs_df_urban = tn_cancer_costs.loc[cancer_costs_df['urban'] == 'Urban']
cancer_costs_df_urban.analysis_value.describe()
# Out:
# count       38.000000
# mean     19638.605263
# std       2712.218435
# min      15454.000000
# 25%      17674.750000
# 50%      19203.500000
# 75%      20556.750000
# max      27740.000000
# Name: analysis_value, dtype: float64

# %%
cancer_costs_df_rural = tn_cancer_costs.loc[cancer_costs_df['urban'] == 'Rural']
cancer_costs_df_rural.analysis_value.describe()
# Out:
# count       57.000000
# mean     19837.421053
# std       2255.416100
# min      15531.000000
# 25%      18328.000000
# 50%      19633.000000
# 75%      21315.000000
# max      25909.000000
# Name: analysis_value, dtype: float64

# %%
h = tn_ha_costs.analysis_value[tn_ha_costs.urban == 'Urban'].hist(alpha=0.5,bins=25,label='Ha Costs - Urban')
h = tn_ha_costs.analysis_value[tn_ha_costs.urban == 'Rural'].hist(alpha=0.5,bins=25,label='Ha Costs - Rural')
h.legend()

# %%
tn_ha_costs.groupby(['urban']).mean()
# Out:
#          year          fips  analysis_value
# urban
# Rural  2017.0  47086.320755    45773.075472
# Urban  2017.0  47103.789474    45748.921053

# %%
tn_cancer_costs.groupby(['urban']).mean()
# Out:
#          year          fips  analysis_value
# urban
# Rural  2017.0  47089.140351    19837.421053
# Urban  2017.0  47103.789474    19638.605263

# %%
TN_income_edit.head(10)
# Out:
#       state           county  income_bucket  return_count  single_returns  \
# 19752    TN        Tennessee              1         39580           22400
# 19753    TN        Tennessee              2        439770          345410
# 19754    TN        Tennessee              3        717430          398720
# 19755    TN        Tennessee              4        759340          355970
# 19756    TN        Tennessee              5        396810          128390
# 19757    TN        Tennessee              6        241730           43690
# 19758    TN        Tennessee              7        298270           33380
# 19759    TN        Tennessee              8         97920            8640
# 19760    TN  Anderson County              1           390             220
# 19761    TN  Anderson County              2          5170            4010
#
#        joint_returns  head_of_house_returns  exemptions  dependents  elderly  \
# ...

# %%
income_dict = {'1':'Under $1', '2':'Between 1 and $10,000', '3':'Between 10,000 and $25,000', '4':'Between 25,000 and $50,000', '5':'Between 50,000 and $75,000', '6':'Between 75,000 and $100,000', '7':'Between 100,000 and $200,000', '8':'$200,000 or more'}

# %%
TN_income_edit['income_bucket'] = TN_income_edit['income_bucket'].astype(str)
TN_income_edit['income_bucket'] = TN_income_edit['income_bucket'].replace(income_dict)
TN_income_edit.head()
# Out:
#       state     county               income_bucket  return_count  \
# 19752    TN  Tennessee                    Under $1         39580
# 19753    TN  Tennessee       Between 1 and $10,000        439770
# 19754    TN  Tennessee  Between 10,000 and $25,000        717430
# 19755    TN  Tennessee  Between 25,000 and $50,000        759340
# 19756    TN  Tennessee  Between 50,000 and $75,000        396810
#
#        single_returns  joint_returns  head_of_house_returns  exemptions  \
# 19752           22400          14440                    980       60360
# 19753          345410          39920                  49300      443540
# 19754          398720         115040                 189290     1269420
# 19755          355970         217710                 159890     1486710
# 19756          128390         215890                  42240      881020
#
#        dependents  elderly       agi  returns_with_total_inc  total_inc_amt  \
# ...

# %%
income_county_agg = TN_income_edit.groupby(by=['county']).sum().reset_index()
income_county_agg.head()
# Out:
#             county  return_count  single_returns  joint_returns  \
# 0  Anderson County         34290           14990          14030
# 1   Bedford County         20920            8600           8010
# 2    Benton County          6610            2660           2840
# 3   Bledsoe County          4560            1620           2220
# 4    Blount County         59550           25090          26650
#
#    head_of_house_returns  exemptions  dependents  elderly      agi  \
# 0                   4550       65950       19620     9670  1807309
# 1                   3910       43550       15790     4430   971152
# 2                   1000       13020        3890     2000   269227
# 3                    610        9690        3100     1200   178860
# 4                   6550      115820       33400    16880  3333654
#
#    returns_with_total_inc  total_inc_amt  returns_with_unemployment  \
# 0                   34140        1830482                        700
# ...

# %%
income_county_agg_county_only = income_county_agg.loc[income_county_agg['county'] != 'Tennessee'] 
income_county_agg_county_only.loc[income_county_agg_county_only['return_count'].idxmax()]
# Out:
# county                       Shelby County
# return_count                        431650
# single_returns                      205500
# joint_returns                       104290
# head_of_house_returns               112920
# exemptions                          836590
# dependents                          325450
# elderly                              86860
# agi                               25467506
# returns_with_total_inc              430150
# total_inc_amt                     25843890
# returns_with_unemployment             8020
# unemployment_comp                    26306
# Name: 78, dtype: object

# %%
income_county_agg_county_only.loc[income_county_agg_county_only['total_inc_amt'].idxmax()]
# Out:
# county                       Shelby County
# return_count                        431650
# single_returns                      205500
# joint_returns                       104290
# head_of_house_returns               112920
# exemptions                          836590
# dependents                          325450
# elderly                              86860
# agi                               25467506
# returns_with_total_inc              430150
# total_inc_amt                     25843890
# returns_with_unemployment             8020
# unemployment_comp                    26306
# Name: 78, dtype: object

# %%
TN_income_total = TN_income_edit.loc[TN_income_edit['county'] == 'Tennessee']
TN_income_total.head()
# Out:
#       state     county               income_bucket  return_count  \
# 19752    TN  Tennessee                    Under $1         39580
# 19753    TN  Tennessee       Between 1 and $10,000        439770
# 19754    TN  Tennessee  Between 10,000 and $25,000        717430
# 19755    TN  Tennessee  Between 25,000 and $50,000        759340
# 19756    TN  Tennessee  Between 50,000 and $75,000        396810
#
#        single_returns  joint_returns  head_of_house_returns  exemptions  \
# 19752           22400          14440                    980       60360
# 19753          345410          39920                  49300      443540
# 19754          398720         115040                 189290     1269420
# 19755          355970         217710                 159890     1486710
# 19756          128390         215890                  42240      881020
#
#        dependents  elderly       agi  returns_with_total_inc  total_inc_amt  \
# ...

# %%
import matplotlib.pyplot as plt
plt.barh('income_bucket', 'return_count', data=TN_income_total, color = 'red', edgecolor = 'black')
plt.xlabel('Returns')
plt.title('Total Returns by Income in TN');

# %%
import seaborn as sns
sns.barplot(y='income_bucket', x='return_count', data=TN_income_total, color = 'red', edgecolor = 'black')
plt.xlabel('Returns')
plt.title('Total Returns by Income in TN');

# %%
income_county_agg['mean_income'] = 1000*(income_county_agg['total_inc_amt'] / income_county_agg['return_count'])
income_county_agg.head()
# Out:
#             county  return_count  single_returns  joint_returns  \
# 0  Anderson County         34290           14990          14030
# 1   Bedford County         20920            8600           8010
# 2    Benton County          6610            2660           2840
# 3   Bledsoe County          4560            1620           2220
# 4    Blount County         59550           25090          26650
#
#    head_of_house_returns  exemptions  dependents  elderly      agi  \
# 0                   4550       65950       19620     9670  1807309
# 1                   3910       43550       15790     4430   971152
# 2                   1000       13020        3890     2000   269227
# 3                    610        9690        3100     1200   178860
# 4                   6550      115820       33400    16880  3333654
#
#    returns_with_total_inc  total_inc_amt  returns_with_unemployment  \
# 0                   34140        1830482                        700
# ...

# %%
income_county_agg_county_only = income_county_agg.loc[income_county_agg['county'] != 'Tennessee']
income_county_agg_county_only.loc[income_county_agg_county_only['return_count'].idxmax()]
# Out:
# county                       Shelby County
# return_count                        431650
# single_returns                      205500
# joint_returns                       104290
# head_of_house_returns               112920
# exemptions                          836590
# dependents                          325450
# elderly                              86860
# agi                               25467506
# returns_with_total_inc              430150
# total_inc_amt                     25843890
# returns_with_unemployment             8020
# unemployment_comp                    26306
# mean_income                        59872.3
# Name: 78, dtype: object

# %%
plt.hist('mean_income', data=income_county_agg_county_only, color='blue', edgecolor='black')
plt.xlabel('Mean Income')
plt.ylabel('Number of Counties')
plt.title('Distribution of Mean Income in TN Counties');

# %%
income_county_agg_county_only[income_county_agg_county_only.mean_income > 120000]
# Out:
#                county  return_count  single_returns  joint_returns  \
# 94  Williamson County        103130           39860          54520
#
#     head_of_house_returns  exemptions  dependents  elderly       agi  \
# 94                   6880      226210       79870    24130  13101310
#
#     returns_with_total_inc  total_inc_amt  returns_with_unemployment  \
# 94                  102890       13383074                       1430
#
#     unemployment_comp    mean_income
# 94               5125  129768.971201

# %%
ha_data_boxplot = [tn_ha_costs['analysis_value'], ha_costs_df_rural['analysis_value']]
labels=tn_ha_costs['urban'].unique()
plt.boxplot(ha_data_boxplot, labels=labels)
plt.ylabel('Heart Attack Costs')
plt.title('Distribution of Heart Attack Costs in TN Counties');

# %%
ha_data_boxplot = [ha_costs_df_urban['analysis_value'], ha_costs_df_rural['analysis_value']]
labels=tn_ha_costs['urban'].unique()
plt.boxplot(ha_data_boxplot, labels=labels)
plt.ylabel('Heart Attack Costs')
plt.title('Distribution of Heart Attack Costs in TN Counties');

# %%
cancer_data_boxplot = [cancer_costs_df_urban['analysis_value'], cancer_costs_df_rural['analysis_value']]
labels=tn_cancer_costs['urban'].unique()
plt.boxplot(cancer_data_boxplot, labels=labels)
plt.ylabel('Cancer Costs')
plt.title('Distribution of Cancer Costs in TN Counties');

# %%
sns.swarmplot(x='urban', y='analysis_value', data=tn_ha_costs)
plt.xlabel('')
plt.ylabel('Heart Attack Costs')
plt.title("Distribution of Heart Attack Costs in TN Counties");

# %%
sns.swarmplot(x='urban', y='analysis_value', data=tn_cancer_costs)
plt.xlabel('')
plt.ylabel('Cancer Costs')
plt.title("Distribution of Cancer Costs in TN Counties");

# %%
sns.boxplot(data=ha_data_boxplot)
sns.swarmplot(x='urban', y='analysis_value', data=tn_ha_costs, color='black')
plt.xlabel('')
plt.ylabel('Heart Attack Costs')
plt.title("Distribution of Heart Attack Costs in TN Counties");

# %%
sns.boxplot(data=cancer_data_boxplot)
sns.swarmplot(x='urban', y='analysis_value', data=tn_cancer_costs, color='black')
plt.xlabel('')
plt.ylabel('Cancer Costs')
plt.title("Distribution of Cancer Costs in TN Counties");

# %%
tn_ha_costs = tn_ha_costs
tn_cancer_costs = tn_cancer_costs
tn_ha_costs = tn_ha_costs.rename(columns = {'analysis_value':'ha_avg_cost'})
tn_cancer_costs = tn_cancer_costs.rename(columns = {'analysis_value':'cancer_avg_cost'})

# %%
tn_cancer_costs.loc[~tn_cancer_costs.county.isin(tn_ha_costs.county)]
# Out:
#       year geography             measure         adjustment      analysis  \
# 2429  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2459  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2464  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2483  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                                   condition  \
# 2429  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 2459  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 2464  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 2483  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
#
#      primary_sex primary_age     primary_dual   fips            county  \
# 2429         All         All  Dual & non-dual  47067    Hancock County
# ...

# %%
tn_ha_costs_sub = tn_ha_costs[['county', 'ha_avg_cost']]
tn_cancer_costs_sub = tn_cancer_costs[['county', 'urban', 'cancer_avg_cost']]
tn_df = pd.merge(tn_ha_costs_sub, tn_cancer_costs_sub, on='county', how='inner')
tn_df.head(3)
# Out:
#             county  ha_avg_cost  urban  cancer_avg_cost
# 0  Anderson County        42749  Urban            15454
# 1   Bedford County        43661  Rural            19219
# 2    Benton County        44423  Rural            21315

# %%
tn_df.county.nunique()
# Out:
# 91

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(data = tn_df, x = 'ha_avg_cost', y = 'cancer_avg_cost', s = 50,
                hue='urban',
                palette = ['blue', 'orange'],
                edgecolor = 'black')
plt.xlabel('Cost of Heart Attack ($)')
plt.ylabel('Cost of Cancer ($)',)
plt.title('Costs of Heart Attacks and Cancer in Rural and Urban Counties', fontweight = 'bold');

# %%
income_county_agg.head(2)
# Out:
#             county  return_count  single_returns  joint_returns  \
# 0  Anderson County         34290           14990          14030
# 1   Bedford County         20920            8600           8010
#
#    head_of_house_returns  exemptions  dependents  elderly      agi  \
# 0                   4550       65950       19620     9670  1807309
# 1                   3910       43550       15790     4430   971152
#
#    returns_with_total_inc  total_inc_amt  returns_with_unemployment  \
# 0                   34140        1830482                        700
# 1                   20840         985909                        410
#
#    unemployment_comp   mean_income
# 0               2452  53382.385535
# 1               1023  47127.581262

# %%
income_sub = income_county_agg[['county', 'mean_income']]
tn_df = pd.merge(tn_df, income_sub, on = 'county', how = 'inner')
tn_df['ha_cost_income_ratio'] = tn_df['ha_avg_cost'] / tn_df['mean_income']
tn_df['cancer_cost_income_ratio'] = tn_df['cancer_avg_cost'] / tn_df['mean_income']
tn_df
# Out:
#                county  ha_avg_cost  urban  cancer_avg_cost    mean_income  \
# 0     Anderson County        42749  Urban            15454   53382.385535
# 1      Bedford County        43661  Rural            19219   47127.581262
# 2       Benton County        44423  Rural            21315   41296.671710
# 3      Bledsoe County        41240  Rural            19250   39743.640351
# 4       Blount County        38968  Urban            17073   56786.162888
# ..                ...          ...    ...              ...            ...
# 86       Wayne County        40652  Rural            22658   42556.719023
# 87     Weakley County        55139  Rural            20655   44527.315175
# 88       White County        40717  Rural            18515   40296.554850
# 89  Williamson County        61541  Urban            17527  129768.971201
# 90      Wilson County        52387  Urban            20618   67410.847880
#
#     ha_cost_income_ratio  cancer_cost_income_ratio
# ...

# %%
import geopandas as gpd
counties = gpd.read_file('../data/county/tncounty.shp')
counties.head(2)
# Out:
#    OBJECTID     NAME    KEY    SHAPE_AREA      SHAPE_LEN  \
# 0        76  Chester  47023  8.049024e+09  520461.080124
# 1        77    Wayne  47181  2.050741e+10  666520.678598
#
#                                             geometry
# 0  POLYGON ((1137985.762 344601.643, 1137965.070 ...
# 1  POLYGON ((1365052.057 391716.806, 1365746.554 ...

# %%
counties.shape
# Out:
# (95, 6)

# %%
tn_df['county2'] = tn_df.county.str[:-7]

# %%
geo_tn = pd.merge(counties, tn_df, left_on = 'NAME', right_on = 'county2')
geo_tn.head(2)
# Out:
#    OBJECTID     NAME    KEY    SHAPE_AREA      SHAPE_LEN  \
# 0        76  Chester  47023  8.049024e+09  520461.080124
# 1        77    Wayne  47181  2.050741e+10  666520.678598
#
#                                             geometry          county  \
# 0  POLYGON ((1137985.762 344601.643, 1137965.070 ...  Chester County
# 1  POLYGON ((1365052.057 391716.806, 1365746.554 ...    Wayne County
#
#    ha_avg_cost  urban  cancer_avg_cost   mean_income  ha_cost_income_ratio  \
# 0        49264  Urban            23421  43147.147147              1.141767
# 1        40652  Rural            22658  42556.719023              0.955243
#
#    cancer_cost_income_ratio  county2
# 0                  0.542817  Chester
# 1                  0.532419    Wayne

# %%
geo_tn[geo_tn.ha_cost_income_ratio.notnull()].shape
# Out:
# (91, 14)

# %%
fig, ax = plt.subplots(figsize=(16,4))
geo_tn[geo_tn.ha_cost_income_ratio.notnull()].plot(column = 'ha_cost_income_ratio',
                    cmap = 'bwr',
                    edgecolor = 'black',
                    legend = True,
                    ax = ax)
plt.title('Heart Attack Cost to Income Ratio', fontsize = 14)
ax.axis('off');

# %%
fig, ax = plt.subplots(figsize=(16,4))
geo_tn[geo_tn.cancer_cost_income_ratio.notnull()].plot(column = 'cancer_cost_income_ratio',
                    cmap = 'bwr',
                    edgecolor = 'black',
                    legend = True,
                    ax = ax)
plt.title('Cancer Cost to Income Ratio', fontsize = 14)
ax.axis('off');

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

from cm import plot_confusion_matrix

# %%
cancer_costs_df = pd.read_csv('../data/mmd_cancer_data.csv')
cancer_costs_df = cancer_costs_df.rename(columns = {'analysis_value': 'cancer_avg_cost'})
cancer_costs_df = cancer_costs_df[['state', 'county', 'urban', 'cancer_avg_cost']]
cancer_costs_df.head(2)
# Out:
#      state          county  urban  cancer_avg_cost
# 0  ALABAMA  Autauga County  Urban            19293
# 1  ALABAMA  Baldwin County  Rural            17151

# %%
income_df = pd.read_csv('../data/irs_county_2016.csv')
income_df = income_df[['STATE', 'COUNTYNAME', 'N02650', 'A02650']]
income_df.columns = ['state', 'county', 'returns_with_total_inc', 'total_inc_amt']
income_df.head(2)
# Out:
#   state   county  returns_with_total_inc  total_inc_amt
# 0    AL  Alabama                   19140       -1657452
# 1    AL  Alabama                  285760        1632624

# %%
income_agg = income_df.groupby(['state', 'county']).agg('sum').reset_index()
income_agg['avg_income'] = round(income_agg.total_inc_amt * 1000 / income_agg.returns_with_total_inc, 0)
income_agg.head(2)
# Out:
#   state                county  returns_with_total_inc  total_inc_amt  \
# 0    AK                Alaska                  347600       23858011
# 1    AK  Aleutians East Borou                     890          43596
#
#    avg_income
# 0     68636.0
# 1     48984.0

# %%
state_abbrev = pd.read_csv('../data/state_abbrev.csv')
state_abbrev.head(2)
# Out:
#       name abbrev
# 0  ALABAMA     AL
# 1   ALASKA     AK

# %%
cancer_costs_df.head(2)
# Out:
#      state          county  urban  cancer_avg_cost
# 0  ALABAMA  Autauga County  Urban            19293
# 1  ALABAMA  Baldwin County  Rural            17151

# %%
income_df.groupby(['state', 'county']).agg('sum')
# Out:
#                             returns_with_total_inc  total_inc_amt
# state county
# AK    Alaska                                347600       23858011
#       Aleutians East Borou                     890          43596
#       Aleutians West Censu                    2110         128069
#       Anchorage Municipali                  146440       11216452
#       Bethel Census Area                      6750         255422
# ...                                            ...            ...
# WY    Teton County                           14200        3051442
#       Uinta County                            9000         550039
#       Washakie County                         3660         228452
#       Weston County                           3130         193089
#       Wyoming                               268530       19177762
#
# [3191 rows x 2 columns]

# %%
income_agg = income_df.groupby(['state', 'county']).agg('sum').reset_index()
income_agg['avg_income'] = round(income_agg.total_inc_amt * 1000 / income_agg.returns_with_total_inc, 0)
income_agg = income_agg[['state', 'county', 'avg_income']]
income_agg.head(2)
# Out:
#   state                county  avg_income
# 0    AK                Alaska     68636.0
# 1    AK  Aleutians East Borou     48984.0

# %%
cancer_costs_df['state'] = cancer_costs_df['state'].map(state_abbrev.set_index('name')['abbrev'].to_dict())
cancer_costs_df.head(2)
# Out:
#   state          county  urban  cancer_avg_cost
# 0    AL  Autauga County  Urban            19293
# 1    AL  Baldwin County  Rural            17151

# %%
cancer_costs_df = pd.merge(cancer_costs_df, income_agg, on = ['state', 'county'], how = 'inner')
cancer_costs_df.head(2)
# Out:
#   state          county  urban  cancer_avg_cost  avg_income
# 0    AL  Autauga County  Urban            19293     55843.0
# 1    AL  Baldwin County  Rural            17151     62832.0

# %%
cancer_costs_df['cancer_cost_ratio'] = cancer_costs_df['cancer_avg_cost'] / cancer_costs_df['avg_income']
cancer_costs_df.head(2)
# Out:
#   state          county  urban  cancer_avg_cost  avg_income  cancer_cost_ratio
# 0    AL  Autauga County  Urban            19293     55843.0           0.345486
# 1    AL  Baldwin County  Rural            17151     62832.0           0.272966

# %%
avg_cancer_ratio = cancer_costs_df.cancer_cost_ratio.mean()
avg_cancer_ratio
# Out:
# 0.4149767494462453

# %%
cancer_costs_df['above_avg_cancer_ratio'] = cancer_costs_df['cancer_cost_ratio'] > avg_cancer_ratio
cancer_costs_df.head(2)
# Out:
#   state          county  urban  cancer_avg_cost  avg_income  \
# 0    AL  Autauga County  Urban            19293     55843.0
# 1    AL  Baldwin County  Rural            17151     62832.0
#
#    cancer_cost_ratio  above_avg_cancer_ratio
# 0           0.345486                   False
# 1           0.272966                   False

# %%
cancer_costs_df = pd.get_dummies(cancer_costs_df, columns = ['urban'], drop_first = True)
cancer_costs_df.head(3)
# Out:
#   state          county  cancer_avg_cost  avg_income  cancer_cost_ratio  \
# 0    AL  Autauga County            19293     55843.0           0.345486
# 1    AL  Baldwin County            17151     62832.0           0.272966
# 2    AL  Barbour County            19469     40269.0           0.483474
#
#    above_avg_cancer_ratio  urban_Urban
# 0                   False            1
# 1                   False            0
# 2                    True            0

# %%
cancer_costs_df.shape
# Out:
# (3066, 7)

# %%
X = cancer_costs_df[['urban_Urban']]
y = cancer_costs_df.above_avg_cancer_ratio

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2020)

logistic_model = LogisticRegression()
logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
fig, ax = plt.subplots(figsize = (7,5))
sns.barplot(x = logistic_model.coef_[0], y = list(X.columns), ax = ax, edgecolor = 'black')
plt.title('Logistic Regression Coefficients');

# %%
# Model using no predictors
y_test.value_counts(normalize = True)
# Out:
# True     0.500652
# False    0.499348
# Name: above_avg_cancer_ratio, dtype: float64

# %%
y_pred = logistic_model.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.6544980443285529

# %%
plot_confusion_matrix(y_test, y_pred, labels = ['below', 'above'], metric = 'accuracy')

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.71      0.52      0.60       383
#         True       0.62      0.79      0.70       384
#
#     accuracy                           0.65       767
#    macro avg       0.67      0.65      0.65       767
# weighted avg       0.67      0.65      0.65       767

# %%
y_pred_prob = logistic_model.predict_proba(X_test)[:,1]
print(metrics.roc_auc_score(y_test, y_pred_prob))
# Out:
# 0.654325772410792

# %%
fp_rate, tp_rate, thresholds = metrics.roc_curve(y_test, y_pred_prob)

plt.plot(fp_rate, tp_rate)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for Cancer Cost Above Average Classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)

# %%
geographic_info = pd.read_csv('../data/geographic_profile_update.csv')
geographic_info
# Out:
#      state             county  Median Household Income (5y Average)  \
# 0       AL     Autauga County                               53099.0
# 1       AL     Baldwin County                               51365.0
# 2       AL     Barbour County                               33956.0
# 3       AL        Bibb County                               39776.0
# 4       AL      Blount County                               46212.0
# ...    ...                ...                                   ...
# 3215    WY  Sweetwater County                               68233.0
# 3216    WY       Teton County                               75594.0
# 3217    WY       Uinta County                               53323.0
# 3218    WY    Washakie County                               46212.0
# 3219    WY      Weston County                               55640.0
#
#       Median Household Income for +7-person Households (5y Avg.)  \
# 0                                              104659.0
# ...

# %%
geographic_info.isna().sum()
# Out:
# state                                                                    0
# county                                                                   0
# Median Household Income (5y Average)                                     0
# Median Household Income for +7-person Households (5y Avg.)             777
# Median Household Income for 1-person Households (5y Avg.)                0
# Median Household Income for 2-person Households (5y Avg.)                1
# Median Household Income for 3-person Households (5y Avg.)               19
# Median Household Income for 4-person Households (5y Avg.)               39
# Median Household Income for 5-person Households (5y Avg.)              125
# Median Household Income for 6-person Households (5y Avg.)              455
# Percent Below Federal Poverty Level (1y Avg.)                         2389
# Percent Below Federal Poverty Level (5y Avg.)                            0
# ...

# %%
geographic_info = geographic_info[['state', 'county', 'Percent Below Federal Poverty Level (5y Avg.)']]

# %%
geographic_info.head(2)
# Out:
#   state          county  Percent Below Federal Poverty Level (5y Avg.)
# 0    AL  Autauga County                                       0.122660
# 1    AL  Baldwin County                                       0.129938

# %%
cancer_costs_df = pd.merge(left = cancer_costs_df, right = geographic_info)

# %%
cancer_costs_df.shape
# Out:
# (3065, 8)

# %%
cancer_costs_df.head(2)
# Out:
#   state          county  cancer_avg_cost  avg_income  cancer_cost_ratio  \
# 0    AL  Autauga County            19293     55843.0           0.345486
# 1    AL  Baldwin County            17151     62832.0           0.272966
#
#    above_avg_cancer_ratio  urban_Urban  \
# 0                   False            1
# 1                   False            0
#
#    Percent Below Federal Poverty Level (5y Avg.)
# 0                                       0.122660
# 1                                       0.129938

# %%
cancer_costs_df.columns
# Out:
# Index(['state', 'county', 'cancer_avg_cost', 'avg_income', 'cancer_cost_ratio',
#        'above_avg_cancer_ratio', 'urban_Urban',
#        'Percent Below Federal Poverty Level (5y Avg.)'],
#       dtype='object')

# %%
X.shape
# Out:
# (3066, 1)

# %%
X = cancer_costs_df[['urban_Urban', 'Percent Below Federal Poverty Level (5y Avg.)']]
y = cancer_costs_df.above_avg_cancer_ratio
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2020)
logistic_model = LogisticRegression()
logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
fig, ax = plt.subplots(figsize = (7,5))
sns.barplot(x = logistic_model.coef_[0], y = list(X.columns), ax = ax, edgecolor = 'black')
plt.title('Logistic Regression Coefficients')
ymin, ymax = plt.ylim()
plt.vlines(x = 0, ymin = ymin, ymax = ymax);

# %%
y_pred = logistic_model.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.7405475880052151

# %%
plot_confusion_matrix(y_test, y_pred, labels = ['below', 'above'], metric = 'accuracy')

# %%
y_pred_prob = logistic_model.predict_proba(X_test)[:,1]

print(metrics.roc_auc_score(y_test, y_pred_prob))
# Out:
# 0.8011536994660565

# %%
fp_rate, tp_rate, thresholds = metrics.roc_curve(y_test, y_pred_prob)

plt.plot(fp_rate, tp_rate)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for Cancer Cost Above Average Classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz

from IPython.display import SVG

# %%
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_train = tree.predict(X_train)
print(metrics.accuracy_score(y_train, y_pred_train))
# Out:
# 1.0

# %%
y_pred = tree.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.6323337679269883

# %%
forest = RandomForestClassifier()
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_train = forest.predict(X_train)
print(metrics.accuracy_score(y_train, y_pred_train))
# Out:
# 1.0

# %%
y_pred = forest.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.6323337679269883

# %%
forest = RandomForestClassifier(n_estimators = 1000, max_depth = 5, min_samples_leaf = 5)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, min_samples_leaf=5, n_estimators=1000)

# %%
y_pred_train = forest.predict(X_train)
print(metrics.accuracy_score(y_train, y_pred_train))
# Out:
# 0.7310704960835509

# %%
y_pred = forest.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.7431551499348109

# %%
fig, ax = plt.subplots(figsize = (7,5))
sns.barplot(x = forest.feature_importances_, y = list(X.columns), ax = ax, edgecolor = 'black')
plt.title('Random Forest Feature Importance');
